# %% [markdown]
# # AIB to Bambora SF Cost Comparison Application

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
import sys
print (sys.version)
# Out:
# <style>.container { width:95% !important; }</style>
# 2.7.12 |Anaconda 4.2.0 (64-bit)| (default, Jun 29 2016, 11:07:13) [MSC v.1500 64 bit (AMD64)]

# %% [markdown]
# ## Import the Necessary Libraries
# Below are the libraries required to assemble the project.

# %%
import pyodbc #CONNECT VIA PYODBC IMPORT THE PYODBC LIBRARY
import pandas as pd #CONNECT TO THE PANDAS LIBRARY
import numpy as np #IMPORT NUMPY
import csv
import seaborn as sns
# %matplotlib inline
from matplotlib import pyplot as plt
from matplotlib.ticker import MultipleLocator
pd.options.mode.chained_assignment = None  # default='warn'
pd.options.display.float_format = '{:,.2f}'.format
#print pyodbc.dataSources()
#conn=pyodbc.connect("Driver={NetezzaSQL};SERVER=10.80.10.70;PORT=5480;DATABASE=P_FDW;UID=djohnson;PWD=Sup3rm4n",ansi=True)

# %% [markdown]
# ## Bambora Pull
#
# As the data is queried the transaction amounts are rounded.<br>
# The transaction amounts are rounded to allow for flow data to be matched between AIB and Bambora.<br>
# For example, England - Netherlands where the transaction amount is 20.00 and not 20.15 or 20.13 is much easier to match.<br>
#
# The non-uniformity of transaction amounts that were not rounded lead to memory issues.<br>
# The process was too laborious because the unqiue transaction amounts led to very large datasets have to be queried against another very large dataset.<br>
# This decision allows for efficiency.

# %%
#Bambora
bb=pd.read_sql(
'''
SELECT 
bb.BAMBORA_REF
,TO_CHAR(bb.SETTLEMENT_DATE, 'MM') AS MONTH
,TO_CHAR(bb.SETTLEMENT_DATE, 'DD') AS DAY
,TO_CHAR(bb.SETTLEMENT_DATE, 'YYYY') AS YEAR
,TO_CHAR(bb.SETTLEMENT_DATE,'YYYY-MM') AS PERIOD
,bb.CONTRACT_ID, bb.ISSUER_COUNTRY_NAME, bb.MERCHANT_COUNTRY_NAME,bb.TRANSACTION_TYPE,bb.CARD_SCHEME,bb.CREDIT_DEBIT,bb.CONSUMER_CORPORATE
,bb.SF_FIXED_FEE_RESULT,bb.SF_PERC_FEE_RESULT,bb.TRANSACTION_TYPE AS B_TRANSACTION_TYPE,bb.CONSUMER_CORPORATE AS C_TYPE
,bb.VOLUME AS VOLUME,ROUND(bb.TRANSACTION_AMOUNT_EUR) AS FLOW,bb.SCHEME_TOTAL_FEE_EUR AS SF,bb.SF_FIXED_FEE,bb. SF_PERC_FEE,bb.TRANSACTION_AMOUNT_EUR
,BB.INTERCHANGE_TOTAL_FEE_EUR,BB.INTERCHANGE_TOTAL_FEE_EUR/bb.TRANSACTION_AMOUNT_EUR AS IC_BPS,BB.SCHEME_TOTAL_FEE_EUR/bb.TRANSACTION_AMOUNT_EUR AS SF_BPS
FROM DATA.ACQUIRER_BAMBORA_COST bb
WHERE bb.TRANSACTION_TYPE='TRANSACTION'
AND bb.SETTLEMENT_DATE BETWEEN '11-01-2017' AND '03-17-2018'
'''
,conn)

# %% [markdown]
# ## AIB Pull
# As the data is queried the transaction amounts are rounded.<br>
# The transaction amounts are rounded to allow for flow data to be matched between AIB and Bambora.<br>
#
# The AIB is Averaged and the Flow amount is rounded

# %%
#AIB
ab=pd.read_sql(
'''
SELECT 
MAX(TRANSACTION_DATE) AS TRANSACTION_DATE,
ab.CONTRACT_ID, ab.ISSUER_COUNTRY, ab.CARD_BRAND, ab.CLEARING_COUNTRY_NAME,ab.TRANSACTION_TYPE
,ROUND(ab.TRANSACTION_FLOW_EUR) AS FLOW,AVG((ABS(ab.SCHEME_FEE_EUR)) )AS SF ,

CASE WHEN ab.CARD_TYPE_GROUP LIKE '%Debit%' THEN 'Debit'
WHEN ab.CARD_TYPE_GROUP LIKE '%Credit%' THEN 'Credit'
WHEN ab.CARD_TYPE_GROUP LIKE '%Prepaid%' THEN 'Prepaid'
END AS "CREDIT_DEBIT",

CASE WHEN ab.CARD_TYPE_GROUP LIKE '%Consumer%' THEN 'Consumer'
WHEN ab.CARD_TYPE_GROUP LIKE '%Commercial%' THEN 'Commercial'
END AS "CARD_TYPE"

FROM DATA.ACQUIRER_AIB_NEWGEN_FILES ab
WHERE ab.TRANSACTION_DATE BETWEEN '11-01-2017' AND '12-31-2017'
AND ab.SCHEME_FEE_EUR!=0
AND (ab.TRANSACTION_TYPE ='Sale')
AND (ab.INTERCHANGE_REGION='Intra-region'OR ab.INTERCHANGE_REGION='Inter-region' OR ab.INTERCHANGE_REGION='Domestic')
GROUP BY  ab.CONTRACT_ID, ab.ISSUER_COUNTRY, ab.CARD_BRAND, ab.CLEARING_COUNTRY_NAME,ab.TRANSACTION_TYPE,CREDIT_DEBIT,CARD_TYPE_GROUP,TRANSACTION_FLOW_EUR
'''
,conn)

# %% [markdown]
# ### Save the AIB Query to hard drive to Prevent Repeated Query Pulls

# %% [markdown]
# ## AIB Import

# %%
ab=pd.read_csv('d:\\djohnson\\Desktop\\bb_aib_aib.csv',skiprows=28,nrows=8586413, error_bad_lines=False, delimiter=';',index_col=False)

# %%
ab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8586391 entries, 0 to 8586390
# Data columns (total 13 columns):
# TRANSACTION_DATE                                                                                              object
# ISSUER_COUNTRY                                                                                                object
# CARD_BRAND                                                                                                    object
# CLEARING_COUNTRY_NAME                                                                                         object
# TRANSACTION_TYPE                                                                                              object
# TRANSACTION_FLOW_EUR                                                                                          float64
# SCHEME_FEE_EUR                                                                                                float64
# INTERCHANGE_EUR                                                                                               float64
# INTERCHANGE_RATE_AMOUNT                                                                                       float64
# INTERCHANGE_RATE_PERC                                                                                         float64
# IC_BPS                                                                                                        float64
# CREDIT_DEBIT                                                                                                  object
# Consumer                                                                                                      object
# dtypes: float64(6), object(7)
# memory usage: 851.6+ MB

# %%
ab=ab.rename(columns={"15-FEB-18":"TRANSACTION_DATE","United Kingdom":"ISSUER_COUNTRY","MasterCard":"CARD_BRAND"
                   ,"United Kingdom.1":"CLEARING_COUNTRY_NAME","Sale":"TRANSACTION_TYPE","56":"TRANSACTION_FLOW_EUR"
                   ,".062932090909090909090909090909090909091":"SCHEME_FEE_EUR",".167447363636363636363636363636363636364":"INTERCHANGE_EUR"
                   ,"0":"INTERCHANGE_RATE_AMOUNT",".3":"INTERCHANGE_RATE_PERC",".002990131493506493506493506493506493506":"IC_BPS"
                   ,"Credit":"CREDIT_DEBIT","Consumer":"CARD_TYPE"})

# %%
ab
# Out:
#                TRANSACTION_DATE         ISSUER_COUNTRY  CARD_BRAND  \
# 0                     15-FEB-18          United States        Visa
# 1                     15-MAR-18                 France        Visa
# 2                     14-FEB-18            Philippines  MasterCard
# 3                     14-FEB-18     Russian Federation        Visa
# 4                     11-FEB-18                 Taiwan  MasterCard
# 5                     15-FEB-18    Korea - Republic of  MasterCard
# 6                     15-FEB-18         United Kingdom        Visa
# 7                     03-MAR-18                Finland        Visa
# 8                     07-MAR-18             Luxembourg        Visa
# 9                     15-FEB-18                 Poland        Visa
# 10                    13-MAR-18         United Kingdom        Visa
# 11                    15-FEB-18                 Cyprus        Visa
# 12                    15-FEB-18                Austria  MasterCard
# 13                    15-FEB-18                Ukraine  MasterCard
# 14                    11-FEB-18    Korea - Republic of  MasterCard
# 15                    14-FEB-18                 Turkey  MasterCard
# 16                    16-MAR-18                  Spain        Visa
# 17                    15-FEB-18  Moldova - Republic of        Visa
# 18                    14-FEB-18             Costa Rica  MasterCard
# 19                    14-FEB-18            New Zealand        Visa
# 20                    15-MAR-18                Denmark  MasterCard
# 21                    15-FEB-18             Kazakhstan        Visa
# 22                    15-FEB-18           Saudi Arabia        Visa
# 23                    15-FEB-18          United States        Visa
# 24                    14-FEB-18                 Taiwan        Visa
# 25                    15-FEB-18          United States  MasterCard
# 26                    16-MAR-18          United States  MasterCard
# 27                    15-FEB-18                 Poland        Visa
# 28                    11-FEB-18    Korea - Republic of        Visa
# 29                    15-FEB-18          United States  MasterCard
# ...                         ...                    ...         ...
# 8586361               14-MAR-18                  Italy  MasterCard
# 8586362               13-MAR-18                  Japan        Visa
# 8586363               13-MAR-18            Netherlands  MasterCard
# 8586364               09-MAR-18            Philippines  MasterCard
# 8586365               13-MAR-18                 Poland  MasterCard
# 8586366               13-MAR-18                 Serbia        Visa
# 8586367               13-MAR-18              Singapore  MasterCard
# 8586368               13-MAR-18            Switzerland  MasterCard
# 8586369               13-MAR-18                   Peru        Visa
# 8586370               13-MAR-18                  Japan        Visa
# 8586371               13-MAR-18                  Italy     Maestro
# 8586372               13-MAR-18              Singapore        Visa
# 8586373               14-MAR-18                 Sweden  MasterCard
# 8586374               14-MAR-18                 Canada        Visa
# 8586375               14-MAR-18                  India  MasterCard
# 8586376               14-MAR-18                 Turkey        Visa
# 8586377               13-MAR-18              Singapore        Visa
# 8586378               14-MAR-18               Bulgaria  MasterCard
# 8586379               14-MAR-18              Australia        Visa
# 8586380               14-MAR-18         United Kingdom        Visa
# 8586381               14-MAR-18            New Zealand  MasterCard
# 8586382               14-MAR-18          United States  MasterCard
# 8586383               14-MAR-18              Guatemala        Visa
# 8586384               13-MAR-18               Thailand        Visa
# 8586385               14-MAR-18                 Canada        Visa
# 8586386               14-MAR-18                Denmark        Visa
# 8586387               14-MAR-18                 Poland        Visa
# 8586388               14-MAR-18                  Japan        Visa
# 8586389  8586390 rows selected.                    NaN         NaN
# 8586390            SQL> spo end                    NaN         NaN
#
#         CLEARING_COUNTRY_NAME TRANSACTION_TYPE  TRANSACTION_FLOW_EUR  \
# 0                      Poland             Sale                 13.00
# 1              United Kingdom             Sale                  5.00
# 2              United Kingdom             Sale                 25.00
# 3              United Kingdom             Sale                  2.00
# 4                     Hungary             Sale                 55.00
# 5                  Luxembourg             Sale                 57.00
# 6                     Ireland             Sale                171.00
# 7              United Kingdom             Sale                  3.00
# 8              United Kingdom             Sale                 20.00
# 9                  Luxembourg             Sale                  1.00
# 10                Netherlands             Sale                 15.00
# 11                 Luxembourg             Sale                  2.00
# 12                     Poland             Sale                 43.00
# 13                 Luxembourg             Sale                 29.00
# 14                    Hungary             Sale                287.00
# 15             United Kingdom             Sale                 19.00
# 16                 Luxembourg             Sale                  2.00
# 17             United Kingdom             Sale                 10.00
# 18             United Kingdom             Sale                 31.00
# 19             United Kingdom             Sale                 28.00
# 20             United Kingdom             Sale                  5.00
# 21                 Luxembourg             Sale                 25.00
# 22             United Kingdom             Sale                142.00
# 23                      Spain             Sale              1,410.00
# 24             United Kingdom             Sale                  1.00
# 25             United Kingdom             Sale                 27.00
# 26                     Poland             Sale                  1.00
# 27                 Luxembourg             Sale                  1.00
# 28                    Hungary             Sale                 52.00
# 29             United Kingdom             Sale                  8.00
# ...                       ...              ...                   ...
# 8586361                Poland             Sale                  8.00
# 8586362               Germany             Sale                271.00
# 8586363            Luxembourg             Sale                  7.00
# 8586364               Hungary             Sale                817.00
# 8586365            Luxembourg             Sale                  3.00
# 8586366            Luxembourg             Sale                 11.00
# 8586367            Luxembourg             Sale                 16.00
# 8586368        United Kingdom             Sale                 95.00
# 8586369            Luxembourg             Sale                  4.00
# 8586370                 Italy             Sale                 21.00
# 8586371           Switzerland             Sale                 79.00
# 8586372        United Kingdom             Sale                 11.00
# 8586373        United Kingdom             Sale                396.00
# 8586374            Luxembourg             Sale                 22.00
# 8586375            Luxembourg             Sale                  4.00
# 8586376            Luxembourg             Sale                  1.00
# 8586377        United Kingdom             Sale                 18.00
# 8586378            Luxembourg             Sale                  2.00
# 8586379            Luxembourg             Sale                  9.00
# 8586380           Switzerland             Sale                110.00
# 8586381            Luxembourg             Sale                 13.00
# 8586382                Poland             Sale                313.00
# 8586383                 Spain             Sale                302.00
# 8586384        United Kingdom             Sale                 28.00
# 8586385        United Kingdom             Sale                125.00
# 8586386                 Italy             Sale                 16.00
# 8586387        United Kingdom             Sale                 12.00
# 8586388            Luxembourg             Sale                 43.00
# 8586389                   NaN              NaN                   nan
# 8586390                   NaN              NaN                   nan
#
#          SCHEME_FEE_EUR  INTERCHANGE_EUR  INTERCHANGE_RATE_AMOUNT  \
# 0                  0.14             0.18                     0.00
# 1                  0.02             0.01                     0.00
# 2                  0.23             0.40                     0.00
# 3                  0.08             0.04                     0.00
# 4                  0.43             1.01                     0.00
# 5                  0.40             0.90                     0.00
# 6                  0.04             0.34                     0.00
# 7                  0.02             0.01                     0.00
# 8                  0.02             0.04                     0.00
# 9                  0.02             0.00                     0.00
# 10                 0.02             0.03                     0.00
# 11                 0.02             0.00                     0.00
# 12                 0.05             0.09                     0.00
# 13                 0.16             0.43                     0.00
# 14                 1.75             4.57                     0.00
# 15                 0.12             0.33                     0.00
# 16                 0.02             0.00                     0.00
# 17                 0.12             0.15                     0.00
# 18                 0.26             0.58                     0.00
# 19                 0.22             0.45                     0.00
# 20                 0.04             0.01                     0.00
# 21                 0.20             0.39                     0.00
# 22                 0.85             2.56                     0.00
# 23                 7.82            25.37                     0.00
# 24                 0.08             0.01                     0.00
# 25                 0.24             0.54                     0.00
# 26                 0.10             0.02                     0.00
# 27                 0.02             0.00                     0.00
# 28                 0.36             0.83                     0.00
# 29                 0.13             0.12                     0.00
# ...                 ...              ...                      ...
# 8586361            0.04             0.02                     0.00
# 8586362            1.54             4.81                     0.00
# 8586363            0.05             0.12                     0.00
# 8586364            4.79            13.02                     0.00
# 8586365            0.04             0.01                     0.00
# 8586366            0.13             0.17                     0.00
# 8586367            0.18             0.30                     0.00
# 8586368            0.47             1.62                     0.00
# 8586369            0.09             0.06                     0.00
# 8586370            0.18             0.33                     0.00
# 8586371            0.42             0.88                     0.05
# 8586372            0.13             0.19                     0.00
# 8586373            0.26             1.18                     0.00
# 8586374            0.19             0.35                     0.00
# 8586375            0.11             0.07                     0.00
# 8586376            0.02             0.00                     0.00
# 8586377            0.17             0.32                     0.00
# 8586378            0.04             0.00                     0.00
# 8586379            0.12             0.15                     0.00
# 8586380            0.50             0.16                     0.16
# 8586381            0.16             0.20                     0.00
# 8586382            1.72             4.79                     0.00
# 8586383            1.72             4.79                     0.00
# 8586384            0.22             0.45                     0.00
# 8586385            0.76             2.00                     0.00
# 8586386            0.02             0.03                     0.00
# 8586387            0.02             0.04                     0.00
# 8586388            0.30             0.76                     0.00
# 8586389             nan              nan                      nan
# 8586390             nan              nan                      nan
#
#          INTERCHANGE_RATE_PERC  IC_BPS CREDIT_DEBIT  \
# 0                         1.44    0.01       Credit
# 1                         0.20    0.00        Debit
# 2                         1.60    0.02       Credit
# 3                         1.80    0.02        Debit
# 4                         1.85    0.02       Credit
# 5                         1.60    0.02       Credit
# 6                         0.20    0.00        Debit
# 7                         0.20    0.00        Debit
# 8                         0.20    0.00      Prepaid
# 9                         0.20    0.00        Debit
# 10                        0.20    0.00        Debit
# 11                        0.20    0.00      Prepaid
# 12                        0.20    0.00      Prepaid
# 13                        1.49    0.01        Debit
# 14                        1.60    0.02       Credit
# 15                        1.73    0.02       Credit
# 16                        0.20    0.00      Prepaid
# 17                        1.60    0.02        Debit
# 18                        1.85    0.02       Credit
# 19                        1.60    0.02       Credit
# 20                        0.20    0.00        Debit
# 21                        1.60    0.02        Debit
# 22                        1.80    0.02       Credit
# 23                        1.80    0.02       Credit
# 24                        1.97    0.01       Credit
# 25                        2.00    0.02          NaN
# 26                        1.60    0.02       Credit
# 27                        0.20    0.00        Debit
# 28                        1.60    0.02       Credit
# 29                        1.60    0.01        Debit
# ...                        ...     ...          ...
# 8586361                   0.20    0.00      Prepaid
# 8586362                   1.80    0.02       Credit
# 8586363                   1.90    0.02          NaN
# 8586364                   1.60    0.02       Credit
# 8586365                   0.30    0.00       Credit
# 8586366                   1.60    0.02       Credit
# 8586367                   1.85    0.02        Debit
# 8586368                   1.70    0.02       Credit
# 8586369                   1.60    0.02        Debit
# 8586370                   1.60    0.02       Credit
# 8586371                   1.05    0.01        Debit
# 8586372                   1.80    0.02        Debit
# 8586373                   0.30    0.00       Credit
# 8586374                   1.60    0.02        Debit
# 8586375                   1.85    0.02       Credit
# 8586376                   0.20    0.00        Debit
# 8586377                   1.80    0.02       Credit
# 8586378                   0.20    0.00        Debit
# 8586379                   1.60    0.02        Debit
# 8586380                   0.00    0.00        Debit
# 8586381                   1.60    0.02       Credit
# 8586382                   1.54    0.02       Credit
# 8586383                   1.60    0.02       Credit
# 8586384                   1.60    0.02        Debit
# 8586385                   1.60    0.02       Credit
# 8586386                   0.20    0.00        Debit
# 8586387                   0.30    0.00       Credit
# 8586388                   1.80    0.02       Credit
# 8586389                    nan     nan          NaN
# 8586390                    nan     nan          NaN
#
#         Consumer
# 0        Consumer                                      ...
# 1        Consumer                                      ...
# 2        Consumer                                      ...
# 3        Consumer                                      ...
# 4        Consumer                                      ...
# 5        Consumer                                      ...
# 6        Consumer                                      ...
# 7        Consumer                                      ...
# 8        Consumer                                      ...
# 9        Consumer                                      ...
# 10       Consumer                                      ...
# 11       Consumer                                      ...
# 12       Consumer                                      ...
# 13       Consumer                                      ...
# 14       Consumer                                      ...
# 15       Consumer                                      ...
# 16       Consumer                                      ...
# 17       Consumer                                      ...
# 18       Consumer                                      ...
# 19       Consumer                                      ...
# 20       Consumer                                      ...
# 21       Consumer                                      ...
# 22       Consumer                                      ...
# 23       Consumer                                      ...
# 24       Consumer                                      ...
# 25       Commercial                                    ...
# 26       Consumer                                      ...
# 27       Consumer                                      ...
# 28       Consumer                                      ...
# 29       Consumer                                      ...
# ...                                                    ...
# 8586361  Consumer                                      ...
# 8586362  Consumer                                      ...
# 8586363  Commercial                                    ...
# 8586364  Consumer                                      ...
# 8586365  Consumer                                      ...
# 8586366  Consumer                                      ...
# 8586367  Consumer                                      ...
# 8586368  Consumer                                      ...
# 8586369  Consumer                                      ...
# 8586370  Consumer                                      ...
# 8586371  Consumer                                      ...
# 8586372  Consumer                                      ...
# 8586373  Consumer                                      ...
# 8586374  Consumer                                      ...
# 8586375  Consumer                                      ...
# 8586376  Consumer                                      ...
# 8586377  Consumer                                      ...
# 8586378  Consumer                                      ...
# 8586379  Consumer                                      ...
# 8586380  Consumer                                      ...
# 8586381  Consumer                                      ...
# 8586382  Consumer                                      ...
# 8586383  Consumer                                      ...
# 8586384  Consumer                                      ...
# 8586385  Consumer                                      ...
# 8586386  Consumer                                      ...
# 8586387  Consumer                                      ...
# 8586388  Consumer                                      ...
# 8586389                                                NaN
# 8586390                                                NaN
#
# [8586391 rows x 13 columns]

# %% [markdown]
# ## Create a Working Copy of the Bambora Data

# %%
bb1=bb.copy() #create working copy of the Bambora data

# %% [markdown]
# ### Remove Bambora Whitespace

# %%
bb1['ISSUER_COUNTRY_NAME']=bb1['ISSUER_COUNTRY_NAME'].str.strip()
bb1['MERCHANT_COUNTRY_NAME']=bb1['MERCHANT_COUNTRY_NAME'].str.strip()

# %% [markdown]
# ### Remove Excess Naming from SQL

# %%
bb1=bb1.drop(['B_TRANSACTION_TYPE','C_TYPE','VOLUME','TRANSACTION_AMOUNT_EUR','SF_FIXED_FEE_RESULT','SF_PERC_FEE_RESULT'],axis=1)

# %% [markdown]
# ## Rename Columns to Allow for Merge

# %%
bb1=bb1.rename(columns={'ISSUER_COUNTRY_NAME':'ISSUER_COUNTRY','MERCHANT_COUNTRY_NAME':'CLEARING_COUNTRY_NAME','CONSUMER_CORPORATE':'CARD_TYPE','CARD_SCHEME':'CARD_BRAND'})

# %%
print bb1.head()
# Out:
#                BAMBORA_REF MONTH DAY  YEAR   PERIOD  CONTRACT_ID  \
# 0  74541097315024958871649    11  11  2017  2017-11     5,859.00
# 1  74541097315024958872282    11  11  2017  2017-11     7,793.00
# 2  74541097315024958871631    11  11  2017  2017-11     5,859.00
# 3  25336247315024958871666    11  11  2017  2017-11     5,859.00
# 4  74541097315024958872266    11  11  2017  2017-11     7,793.00
#
#   ISSUER_COUNTRY CLEARING_COUNTRY_NAME TRANSACTION_TYPE  CARD_BRAND  \
# 0    New Zealand                 China      TRANSACTION        Visa
# 1    New Zealand                 China      TRANSACTION        Visa
# 2    New Zealand                 China      TRANSACTION        Visa
# 3    New Zealand                 China      TRANSACTION  Mastercard
# 4    New Zealand                 China      TRANSACTION        Visa
#
#   CREDIT_DEBIT CARD_TYPE  FLOW   SF  SF_FIXED_FEE  SF_PERC_FEE
# 0        Debit  Consumer 20.00 0.18          0.10         0.01
# 1        Debit  Consumer 16.00 0.16          0.10         0.01
# 2       Credit  Consumer 36.00 0.28          0.10         0.01
# 3        Debit  Consumer 10.00 0.08          0.04         0.01
# 4       Credit  Consumer 16.00 0.16          0.10         0.01

# %% [markdown]
# ## Indentify Congruent Lanes

# %%
bb1_contracts=bb1[['CONTRACT_ID','ISSUER_COUNTRY','CLEARING_COUNTRY_NAME','CARD_BRAND','CREDIT_DEBIT','CARD_TYPE']].drop_duplicates()

# %% [markdown]
# ### Remove Excess Naming

# %%
ab=ab.drop(['TRANSACTION_TYPE','TRANSACTION_DATE'],axis=1)

# %%
print ab.head()
# Out:
#    CONTRACT_ID  ISSUER_COUNTRY  CARD_BRAND CLEARING_COUNTRY_NAME   FLOW   SF  \
# 0         5100         Ireland        Visa               Germany  44.00 0.02
# 1         4235          Canada        Visa        United Kingdom   4.00 0.09
# 2         1423  United Kingdom        Visa        United Kingdom 159.00 0.06
# 3         4235         Finland        Visa        United Kingdom   6.00 0.02
# 4         2443     Switzerland  MasterCard                 Italy  40.00 0.22
#
#   CREDIT_DEBIT CARD_TYPE
# 0        Debit  Consumer
# 1       Credit  Consumer
# 2       Credit  Consumer
# 3        Debit  Consumer
# 4       Credit  Consumer

# %% [markdown]
# ## Attach AIB Lanes to Active Bambora Lanes
# This is a left join that will show all active Bambora lanes on only those AIB lanes where there is congruence.

# %%
ab_df=pd.merge(bb1_contracts,ab,on=['CONTRACT_ID','ISSUER_COUNTRY','CLEARING_COUNTRY_NAME','CARD_BRAND','CREDIT_DEBIT','CARD_TYPE'],how='left')

# %%
bb1_contracts=None #clear the merge data
ab=None #clear the merge data

# %% [markdown]
# ### Only show those lanes where there is activity for AIB and Bambora
# This is done but filtering to only those results that have scheme fee information

# %%
ab_df=ab_df[(ab_df['SF']>0)].drop_duplicates()

# %% [markdown]
# ### Only Show the Median aggregated by lane, contract ID, Credit/Debit and Card type, Flow

# %%
ab_df=ab_df.groupby(['CONTRACT_ID','ISSUER_COUNTRY','CARD_BRAND','CLEARING_COUNTRY_NAME','CREDIT_DEBIT','CARD_TYPE','FLOW'],as_index=False)['SF'].median()

# %%
print ab_df.head()
# Out:
#    CONTRACT_ID ISSUER_COUNTRY CARD_BRAND CLEARING_COUNTRY_NAME CREDIT_DEBIT  \
# 0     1,946.00        Albania       Visa            Luxembourg       Credit
# 1     1,946.00        Albania       Visa            Luxembourg       Credit
# 2     1,946.00        Albania       Visa            Luxembourg       Credit
# 3     1,946.00        Albania       Visa            Luxembourg       Credit
# 4     1,946.00        Albania       Visa            Luxembourg       Credit
#
#   CARD_TYPE  FLOW   SF
# 0  Consumer  0.00 0.08
# 1  Consumer  1.00 0.08
# 2  Consumer  2.00 0.08
# 3  Consumer  3.00 0.09
# 4  Consumer  4.00 0.09

# %%
ab_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22731 entries, 0 to 22730
# Data columns (total 8 columns):
# CONTRACT_ID              22731 non-null float64
# ISSUER_COUNTRY           22731 non-null object
# CARD_BRAND               22731 non-null object
# CLEARING_COUNTRY_NAME    22731 non-null object
# CREDIT_DEBIT             22731 non-null object
# CARD_TYPE                22731 non-null object
# FLOW                     22731 non-null float64
# SF                       22731 non-null float64
# dtypes: float64(3), object(5)
# memory usage: 1.6+ MB

# %% [markdown]
# ## Setup the Bambora Baseline Lanes, Flows, and SFs

# %%
base=ab_df.drop(['FLOW','SF'],axis=1).drop_duplicates()

# %%
bbbase=pd.merge(base,bb1,on=['CONTRACT_ID','ISSUER_COUNTRY','CLEARING_COUNTRY_NAME','CARD_BRAND','CREDIT_DEBIT','CARD_TYPE'],how='left')

# %%
bbbase.head()
# Out:
#    CONTRACT_ID ISSUER_COUNTRY CARD_BRAND CLEARING_COUNTRY_NAME CREDIT_DEBIT  \
# 0     1,946.00        Albania       Visa            Luxembourg       Credit
# 1     1,946.00        Albania       Visa            Luxembourg       Credit
# 2     1,946.00        Albania       Visa            Luxembourg       Credit
# 3     1,946.00        Albania       Visa            Luxembourg       Credit
# 4     1,946.00        Albania       Visa            Luxembourg       Credit
#
#   CARD_TYPE              BAMBORA_REF MONTH DAY  YEAR   PERIOD  \
# 0  Consumer  74541097317024983622411    11  13  2017  2017-11
# 1  Consumer  74541097317024983612529    11  13  2017  2017-11
# 2  Consumer  74541097317024983727038    11  13  2017  2017-11
# 3  Consumer  74541097317024984047204    11  13  2017  2017-11
# 4  Consumer  74541097317024984169347    11  13  2017  2017-11
#
#   TRANSACTION_TYPE  FLOW   SF  SF_FIXED_FEE  SF_PERC_FEE
# 0      TRANSACTION  5.00 0.09          0.06         0.01
# 1      TRANSACTION 12.00 0.13          0.06         0.01
# 2      TRANSACTION  8.00 0.11          0.06         0.01
# 3      TRANSACTION  1.00 0.07          0.07         0.01
# 4      TRANSACTION  4.00 0.08          0.07         0.01

# %%
bbbase.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 118177 entries, 0 to 118176
# Data columns (total 16 columns):
# CONTRACT_ID              118177 non-null float64
# ISSUER_COUNTRY           118177 non-null object
# CARD_BRAND               118177 non-null object
# CLEARING_COUNTRY_NAME    118177 non-null object
# CREDIT_DEBIT             118177 non-null object
# CARD_TYPE                118177 non-null object
# BAMBORA_REF              118177 non-null object
# MONTH                    118177 non-null object
# DAY                      118177 non-null object
# YEAR                     118177 non-null object
# PERIOD                   118177 non-null object
# TRANSACTION_TYPE         118177 non-null object
# FLOW                     118177 non-null float64
# SF                       118177 non-null float64
# SF_FIXED_FEE             118177 non-null float64
# SF_PERC_FEE              118177 non-null float64
# dtypes: float64(5), object(11)
# memory usage: 15.3+ MB

# %% [markdown]
# ### Link AIB and Bambora

# %%
ab_bb_comp=pd.merge(bbbase,ab_df,on=['CONTRACT_ID','ISSUER_COUNTRY','CARD_BRAND','CLEARING_COUNTRY_NAME','CREDIT_DEBIT','CARD_TYPE','FLOW'],how='left',suffixes=('_BB','_AVG_AB'))

# %%
ab_bb_comp.head()
# Out:
#    CONTRACT_ID ISSUER_COUNTRY CARD_BRAND CLEARING_COUNTRY_NAME CREDIT_DEBIT  \
# 0     1,946.00        Albania       Visa            Luxembourg       Credit
# 1     1,946.00        Albania       Visa            Luxembourg       Credit
# 2     1,946.00        Albania       Visa            Luxembourg       Credit
# 3     1,946.00        Albania       Visa            Luxembourg       Credit
# 4     1,946.00        Albania       Visa            Luxembourg       Credit
#
#   CARD_TYPE              BAMBORA_REF MONTH DAY  YEAR   PERIOD  \
# 0  Consumer  74541097317024983622411    11  13  2017  2017-11
# 1  Consumer  74541097317024983612529    11  13  2017  2017-11
# 2  Consumer  74541097317024983727038    11  13  2017  2017-11
# 3  Consumer  74541097317024984047204    11  13  2017  2017-11
# 4  Consumer  74541097317024984169347    11  13  2017  2017-11
#
#   TRANSACTION_TYPE  FLOW  SF_BB  SF_FIXED_FEE  SF_PERC_FEE  SF_AVG_AB
# 0      TRANSACTION  5.00   0.09          0.06         0.01       0.10
# 1      TRANSACTION 12.00   0.13          0.06         0.01       0.14
# 2      TRANSACTION  8.00   0.11          0.06         0.01       0.11
# 3      TRANSACTION  1.00   0.07          0.07         0.01       0.08
# 4      TRANSACTION  4.00   0.08          0.07         0.01       0.09

# %% [markdown]
# ## Insert the Signal logic

# %%
ab_bb_comp['SF_DIFF_%']=(ab_bb_comp['SF_BB']-ab_bb_comp['SF_AVG_AB'])/ab_bb_comp['SF_AVG_AB']

ab_bb_comp['SIGNAL']=''
ab_bb_comp['SIGNAL'][(ab_bb_comp['SF_DIFF_%']>.05)]='Signal'

# %%
ab_bb_comp.head()
# Out:
#    CONTRACT_ID ISSUER_COUNTRY CARD_BRAND CLEARING_COUNTRY_NAME CREDIT_DEBIT  \
# 0     1,946.00        Albania       Visa            Luxembourg       Credit
# 1     1,946.00        Albania       Visa            Luxembourg       Credit
# 2     1,946.00        Albania       Visa            Luxembourg       Credit
# 3     1,946.00        Albania       Visa            Luxembourg       Credit
# 4     1,946.00        Albania       Visa            Luxembourg       Credit
#
#   CARD_TYPE              BAMBORA_REF MONTH DAY  YEAR   PERIOD  \
# 0  Consumer  74541097317024983622411    11  13  2017  2017-11
# 1  Consumer  74541097317024983612529    11  13  2017  2017-11
# 2  Consumer  74541097317024983727038    11  13  2017  2017-11
# 3  Consumer  74541097317024984047204    11  13  2017  2017-11
# 4  Consumer  74541097317024984169347    11  13  2017  2017-11
#
#   TRANSACTION_TYPE  FLOW  SF_BB  SF_FIXED_FEE  SF_PERC_FEE  SF_AVG_AB  \
# 0      TRANSACTION  5.00   0.09          0.06         0.01       0.10
# 1      TRANSACTION 12.00   0.13          0.06         0.01       0.14
# 2      TRANSACTION  8.00   0.11          0.06         0.01       0.11
# 3      TRANSACTION  1.00   0.07          0.07         0.01       0.08
# 4      TRANSACTION  4.00   0.08          0.07         0.01       0.09
#
#    SF_DIFF_% SIGNAL
# 0      -0.07
# 1      -0.04
# 2      -0.06
# 3      -0.17
# 4      -0.10

# %% [markdown]
# ### Final Output

# %%
ab_bb_comp=ab_bb_comp[['BAMBORA_REF','TRANSACTION_TYPE','CONTRACT_ID','MONTH','DAY','YEAR','PERIOD'
                       ,'CARD_BRAND','CARD_TYPE','CREDIT_DEBIT','ISSUER_COUNTRY','CLEARING_COUNTRY_NAME'
                       ,'FLOW','SF_FIXED_FEE','SF_PERC_FEE','SF_BB','SF_AVG_AB','SF_DIFF_%','SIGNAL']]

# %%
ab_bb_comp.head()
# Out:
#                BAMBORA_REF TRANSACTION_TYPE  CONTRACT_ID MONTH DAY  YEAR  \
# 0  74541097317024983622411      TRANSACTION     1,946.00    11  13  2017
# 1  74541097317024983612529      TRANSACTION     1,946.00    11  13  2017
# 2  74541097317024983727038      TRANSACTION     1,946.00    11  13  2017
# 3  74541097317024984047204      TRANSACTION     1,946.00    11  13  2017
# 4  74541097317024984169347      TRANSACTION     1,946.00    11  13  2017
#
#     PERIOD CARD_BRAND CARD_TYPE CREDIT_DEBIT ISSUER_COUNTRY  \
# 0  2017-11       Visa  Consumer       Credit        Albania
# 1  2017-11       Visa  Consumer       Credit        Albania
# 2  2017-11       Visa  Consumer       Credit        Albania
# 3  2017-11       Visa  Consumer       Credit        Albania
# 4  2017-11       Visa  Consumer       Credit        Albania
#
#   CLEARING_COUNTRY_NAME  FLOW  SF_FIXED_FEE  SF_PERC_FEE  SF_BB  SF_AVG_AB  \
# 0            Luxembourg  5.00          0.06         0.01   0.09       0.10
# 1            Luxembourg 12.00          0.06         0.01   0.13       0.14
# 2            Luxembourg  8.00          0.06         0.01   0.11       0.11
# 3            Luxembourg  1.00          0.07         0.01   0.07       0.08
# 4            Luxembourg  4.00          0.07         0.01   0.08       0.09
#
#    SF_DIFF_% SIGNAL
# 0      -0.07
# 1      -0.04
# 2      -0.06
# 3      -0.17
# 4      -0.10

# %%
print 'total transactions'
print ab_bb_comp['BAMBORA_REF'].count()
print 'total signals'
print ab_bb_comp['BAMBORA_REF'][(ab_bb_comp['SIGNAL']=='Signal')].count()
# Out:
# total transactions
# 118177
# total signals
# 2523

# %%
ab_bb_comp.to_csv('d:\\djohnson\\Desktop\\ab_bb_comp.csv')
